# %%
import pandas as pd

# %%
bank=pd.read_csv("bank-additional-full.csv", sep=";")

# %%
bank
# Out:
#        age          job  marital            education  default housing loan  \
# 0       56    housemaid  married             basic.4y       no      no   no
# 1       57     services  married          high.school  unknown      no   no
# 2       37     services  married          high.school       no     yes   no
# 3       40       admin.  married             basic.6y       no      no   no
# 4       56     services  married          high.school       no      no  yes
# ...    ...          ...      ...                  ...      ...     ...  ...
# 41183   73      retired  married  professional.course       no     yes   no
# 41184   46  blue-collar  married  professional.course       no      no   no
# 41185   56      retired  married    university.degree       no     yes   no
# 41186   44   technician  married  professional.course       no      no   no
# 41187   74      retired  married  professional.course       no     yes   no
#
# ...

# %%
bank.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41188 entries, 0 to 41187
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             41188 non-null  int64
#  1   job             41188 non-null  object
#  2   marital         41188 non-null  object
#  3   education       41188 non-null  object
#  4   default         41188 non-null  object
#  5   housing         41188 non-null  object
#  6   loan            41188 non-null  object
#  7   contact         41188 non-null  object
#  8   month           41188 non-null  object
#  9   day_of_week     41188 non-null  object
#  10  duration        41188 non-null  int64
#  11  campaign        41188 non-null  int64
#  12  pdays           41188 non-null  int64
#  13  previous        41188 non-null  int64
#  14  poutcome        41188 non-null  object
#  15  emp.var.rate    41188 non-null  float64
#  16  cons.price.idx  41188 non-null  float64
# ...

# %%
count={}
for col in bank.columns:
    count[col]=(bank[col]=="unknown").sum()
print(count)
# Out:
# {'age': 0, 'job': 330, 'marital': 80, 'education': 1731, 'default': 8597, 'housing': 990, 'loan': 990, 'contact': 0, 'month': 0, 'day_of_week': 0, 'duration': 0, 'campaign': 0, 'pdays': 0, 'previous': 0, 'poutcome': 0, 'emp.var.rate': 0, 'cons.price.idx': 0, 'cons.conf.idx': 0, 'euribor3m': 0, 'nr.employed': 0, 'y': 0}

# %%
drop=bank[
    (bank["job"]=="unknown")&
    (bank["marital"]=="unknown")&
    (bank["education"]=="unknown")&
    (bank["default"]=="unknown")&
    (bank["housing"]=="unknown")&
    (bank["loan"]=="unknown")
].index
bank_missing_drop1=bank.drop(index=drop)
bank_missing_drop1
# Out:
#        age          job  marital            education  default housing loan  \
# 0       56    housemaid  married             basic.4y       no      no   no
# 1       57     services  married          high.school  unknown      no   no
# 2       37     services  married          high.school       no     yes   no
# 3       40       admin.  married             basic.6y       no      no   no
# 4       56     services  married          high.school       no      no  yes
# ...    ...          ...      ...                  ...      ...     ...  ...
# 41183   73      retired  married  professional.course       no     yes   no
# 41184   46  blue-collar  married  professional.course       no      no   no
# 41185   56      retired  married    university.degree       no     yes   no
# 41186   44   technician  married  professional.course       no      no   no
# 41187   74      retired  married  professional.course       no     yes   no
#
# ...

# %%
(bank_missing_drop1=="unknown").sum().sum()
# Out:
# 12718

# %%
import numpy as np
bank.replace("unknown",np.nan, inplace=True)

# %%
bank.loc[(bank["age"]>56)&(bank["job"].isna()), "job"]='retired'

# %%
bank
# Out:
#        age          job  marital            education default housing loan  \
# 0       56    housemaid  married             basic.4y      no      no   no
# 1       57     services  married          high.school     NaN      no   no
# 2       37     services  married          high.school      no     yes   no
# 3       40       admin.  married             basic.6y      no      no   no
# 4       56     services  married          high.school      no      no  yes
# ...    ...          ...      ...                  ...     ...     ...  ...
# 41183   73      retired  married  professional.course      no     yes   no
# 41184   46  blue-collar  married  professional.course      no      no   no
# 41185   56      retired  married    university.degree      no     yes   no
# 41186   44   technician  married  professional.course      no      no   no
# 41187   74      retired  married  professional.course      no     yes   no
#
# ...

# %%
bank.isnull().sum().sum()
# Out:
# 12667

# %%
bank.loc[(bankdata["loan"]=="yes")&(bankdata["default"].isna()), "default"]='yes'
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 bank.loc[(bankdata["loan"]=="yes")&(bankdata["default"].isna()), "default"]='yes'
#
# NameError: name 'bankdata' is not defined

# %%
bankdata.isnull().sum().sum()

# %%
bank["job"].unique()

# %%
bank['age'].describe()
# Out:
# count    41188.00000
# mean        40.02406
# std         10.42125
# min         17.00000
# 25%         32.00000
# 50%         38.00000
# 75%         47.00000
# max         98.00000
# Name: age, dtype: float64

# %%
bank['age'].plot(kind='hist',bins=30)
# Out:
# <Axes: ylabel='Frequency'>

# %%
bank['age'].plot(kind='kde')
# Out:
# <Axes: ylabel='Density'>

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10, 6))
bank['age'].hist(bins=50, edgecolor='black')
#plt.title('Distribution of Employee Ages', fontsize=14)
#plt.xlabel('Age (years)', fontsize=12)
#plt.ylabel('Number of Employees', fontsize=12)
#plt.xticks(fontsize=10)
#plt.yticks(fontsize=10)
#plt.gca().spines['top'].set_visible(False)
#plt.gca().spines['right'].set_visible(False)
# Out:
# <Axes: >

# %%
import seaborn as sns
sns.boxplot(bank['age'])
# Out:
# <Axes: ylabel='age'>

# %%
Q1 = bank['age'].quantile(0.25)
Q3 = bank['age'].quantile(0.75)
IQR = Q3 - Q1

# Define lower and upper bounds
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Find outliers
outliers = bank[(bank['age'] < lower_bound) | (bank['age'] > upper_bound)]

# %%
print(outliers)
# Out:
#        age      job   marital            education default housing loan  \
# 27713   70  retired  divorced             basic.4y      no     yes   no
# 27757   76  retired   married    university.degree      no      no  yes
# 27780   73  retired   married    university.degree      no     yes   no
# 27800   88  retired  divorced             basic.4y      no     yes   no
# 27802   88  retired  divorced             basic.4y      no      no   no
# ...    ...      ...       ...                  ...     ...     ...  ...
# 40986   84  retired  divorced             basic.4y     NaN     yes  yes
# 40996   81  retired   married             basic.4y      no     yes   no
# 41004   80  retired   married  professional.course      no     yes   no
# 41183   73  retired   married  professional.course      no     yes   no
# 41187   74  retired   married  professional.course      no     yes   no
#
#         contact month day_of_week  ...  campaign  pdays  previous  \
# ...

# %%
bank['y'].value_counts()
# Out:
# y
# no     36548
# yes     4640
# Name: count, dtype: int64

# %%
bank['y'].groupby('job').size()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[45], line 1
# ----> 1 bank['y'].groupby('job').size()
#
# File ~\anaconda3\Lib\site-packages\pandas\core\series.py:2247, in Series.groupby(self, by, axis, level, as_index, sort, group_keys, observed, dropna)
#    2244     raise TypeError("as_index=False only valid with DataFrame")
#    2245 axis = self._get_axis_number(axis)
# -> 2247 return SeriesGroupBy(
#    2248     obj=self,
#    2249     keys=by,
#    2250     axis=axis,
#    2251     level=level,
#    2252     as_index=as_index,
#    2253     sort=sort,
#    2254     group_keys=group_keys,
#    2255     observed=observed,
#    2256     dropna=dropna,
#    2257 )
#
# File ~\anaconda3\Lib\site-packages\pandas\core\groupby\groupby.py:1329, in GroupBy.__init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, observed, dropna)
# ...

# %%
from scipy import stats

# %%
z=stats.zscore(bank['age'])
sz=abs(z)
outliers=bank[sz>3]
z
#outliers
#outliers['age'].value_counts()
# Out:
# 0        1.533034
# 1        1.628993
# 2       -0.290186
# 3       -0.002309
# 4        1.533034
#            ...
# 41183    3.164336
# 41184    0.573445
# 41185    1.533034
# 41186    0.381527
# 41187    3.260295
# Name: age, Length: 41188, dtype: float64

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dtree=DecisionTreeClassifier(
